# %% [markdown]
# # 第5章: 大規模言語モデル
#
# この章では、大規模言語モデル (LLM; Large Language Model) の利用し、様々なタスクに取り組む。大規模言語モデルをプログラムからAPI経由で呼び出すことを想定しており、そのAPIの利用で費用が発生する可能性があることに留意せよ。

# %% [markdown]
# ## 40. Zero-Shot推論
#
# 以下の問題の解答を作成せよ。ただし、解答生成はzero-shot推論とせよ。
#
# ```
# 9世紀に活躍した人物に関係するできごとについて述べた次のア～ウを年代の古い順に正しく並べよ。
#
# ア　藤原時平は，策謀を用いて菅原道真を政界から追放した。
# イ　嵯峨天皇は，藤原冬嗣らを蔵人頭に任命した。
# ウ　藤原良房は，承和の変後，藤原氏の中での北家の優位を確立した。
# ```
#
# 出典: [令和5年度第1回高等学校卒業程度認定試験問題](https://www.mext.go.jp/a_menu/koutou/shiken/kakomon/1411255_00010.htm) [日本史AB 問題](https://www.mext.go.jp/content/20240523-mxt_syogai02-mext_000031286_03nihonshi.pdf) 日本史B 1 問3

# %%
# !pip install -q -U google-genai

# %%
text = """
9世紀に活躍した人物に関係するできごとについて述べた次のア～ウを年代の古い順に正しく並べよ。

ア　藤原時平は，策謀を用いて菅原道真を政界から追放した。
イ　嵯峨天皇は，藤原冬嗣らを蔵人頭に任命した。
ウ　藤原良房は，承和の変後，藤原氏の中での北家の優位を確立した。
"""

# %%
from google.colab import userdata
import google.generativeai as genai

GOOGLE_API_KEY = userdata.get("GEMINI_API_KEY")
genai.configure(api_key=GOOGLE_API_KEY)

model = genai.GenerativeModel("gemini-2.5-flash-lite")

# %%
response = model.generate_content(text)
print(response.text)
# Out:
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1370.95ms
# 年代の古い順に並べると、以下のようになります。
#
# *   **イ**　嵯峨天皇は，藤原冬嗣らを蔵人頭に任命した。
#     *   薬子の変（810年）の直後に、嵯峨天皇によって蔵人所が設置され、藤原冬嗣らが蔵人頭に任命されました。これは**9世紀初頭**の出来事です。
# *   **ウ**　藤原良房は，承和の変後，藤原氏の中での北家の優位を確立した。
#     *   承和の変は842年に起こりました。この変を通じて藤原良房が権力を強化し、藤原北家の地位を確立しました。これは**9世紀中頃**の出来事です。
# *   **ア**　藤原時平は，策謀を用いて菅原道真を政界から追放した。
#     *   これは昌泰の変（菅原道真が大宰府に左遷された事件）のことで、901年に起こりました。これは**10世紀初頭**の出来事です。
#
# したがって、年代の古い順に並べると、**イ → ウ → ア** となります。

# %% [markdown]
# ## 41. Few-Shot推論
#
# 以下の問題と解答を与え、問題40で示した質問の解答をfew-shot推論（この場合は4-shot推論）で生成せよ。
#
# ```
# 日本の近代化に関連するできごとについて述べた次のア～ウを年代の古い順に正しく並べよ。
#
# ア　府知事・県令からなる地方官会議が設置された。
# イ　廃藩置県が実施され，中央から府知事・県令が派遣される体制になった。
# ウ　すべての藩主が，天皇に領地と領民を返還した。
#
# 解答: ウ→イ→ア
# ```
#
# 出典: [令和5年度第1回高等学校卒業程度認定試験問題](https://www.mext.go.jp/a_menu/koutou/shiken/kakomon/1411255_00010.htm) [日本史AB 問題](https://www.mext.go.jp/content/20240523-mxt_syogai02-mext_000031286_03nihonshi.pdf) 日本史A 1 問8
#
#
# ```
# 江戸幕府の北方での対外的な緊張について述べた次の文ア～ウを年代の古い順に正しく並べよ。
#
# ア　レザノフが長崎に来航したが，幕府が冷淡な対応をしたため，ロシア船が樺太や択捉島を攻撃した。
# イ　ゴローウニンが国後島に上陸し，幕府の役人に捕らえられ抑留された。
# ウ　ラクスマンが根室に来航し，漂流民を届けるとともに通商を求めた。
#
# 解答: ウ→ア→イ
# ```
#
# 出典: [令和5年度第1回高等学校卒業程度認定試験問題](https://www.mext.go.jp/a_menu/koutou/shiken/kakomon/1411255_00010.htm) [日本史AB 問題](https://www.mext.go.jp/content/20240523-mxt_syogai02-mext_000031286_03nihonshi.pdf) 日本史B 3 問3
#
# ```
# 中居屋重兵衛の生涯の期間におこったできごとについて述べた次のア～ウを，年代の古い順に正しく並べよ。
#
# ア　アヘン戦争がおこり，清がイギリスに敗北した。
# イ　異国船打払令が出され，外国船を撃退することが命じられた。
# ウ　桜田門外の変がおこり，大老の井伊直弼が暗殺された。
#
# 解答: イ→ア→ウ
# ```
#
# 出典: [令和4年度第1回高等学校卒業程度認定試験問題](https://www.mext.go.jp/a_menu/koutou/shiken/kakomon/1411255_00007.htm) [日本史 問題](https://www.mext.go.jp/content/20240513-mxt_syogai02-mext_00002452_03nihonshi.pdf) 日本史A 1 問1
#
#
# ```
# 加藤高明が外務大臣として提言を行ってから、内閣総理大臣となり演説を行うまでの時期のできごとについて述べた次のア～ウを，年代の古い順に正しく並べよ。
#
# ア　朝鮮半島において，独立を求める大衆運動である三・一独立運動が展開された。
# イ　関東大震災後の混乱のなかで，朝鮮人や中国人に対する殺傷事件がおきた。
# ウ　日本政府が，袁世凱政府に対して二十一カ条の要求を突き付けた。
#
# 解答: ウ→ア→イ
# ```
#
# 出典: [令和4年度第1回高等学校卒業程度認定試験問題](https://www.mext.go.jp/a_menu/koutou/shiken/kakomon/1411255_00007.htm) [日本史 問題](https://www.mext.go.jp/content/20240513-mxt_syogai02-mext_00002452_03nihonshi.pdf) 日本史A 2 問4

# %%
question = """
日本の近代化に関連するできごとについて述べた次のア～ウを年代の古い順に正しく並べよ。

ア　府知事・県令からなる地方官会議が設置された。
イ　廃藩置県が実施され，中央から府知事・県令が派遣される体制になった。
ウ　すべての藩主が，天皇に領地と領民を返還した。

解答: ウ→イ→ア

江戸幕府の北方での対外的な緊張について述べた次の文ア～ウを年代の古い順に正しく並べよ。

ア　レザノフが長崎に来航したが，幕府が冷淡な対応をしたため，ロシア船が樺太や択捉島を攻撃した。
イ　ゴローウニンが国後島に上陸し，幕府の役人に捕らえられ抑留された。
ウ　ラクスマンが根室に来航し，漂流民を届けるとともに通商を求めた。

解答: ウ→ア→イ

中居屋重兵衛の生涯の期間におこったできごとについて述べた次のア～ウを，年代の古い順に正しく並べよ。

ア　アヘン戦争がおこり，清がイギリスに敗北した。
イ　異国船打払令が出され，外国船を撃退することが命じられた。
ウ　桜田門外の変がおこり，大老の井伊直弼が暗殺された。

解答: イ→ア→ウ

加藤高明が外務大臣として提言を行ってから、内閣総理大臣となり演説を行うまでの時期のできごとについて述べた次のア～ウを，年代の古い順に正しく並べよ。

ア　朝鮮半島において，独立を求める大衆運動である三・一独立運動が展開された。
イ　関東大震災後の混乱のなかで，朝鮮人や中国人に対する殺傷事件がおきた。
ウ　日本政府が，袁世凱政府に対して二十一カ条の要求を突き付けた。

解答: ウ→ア→イ

9世紀に活躍した人物に関係するできごとについて述べた次のア～ウを年代の古い順に正しく並べよ。

ア　藤原時平は，策謀を用いて菅原道真を政界から追放した。
イ　嵯峨天皇は，藤原冬嗣らを蔵人頭に任命した。
ウ　藤原良房は，承和の変後，藤原氏の中での北家の優位を確立した。

解答:
"""

# %%
response = model.generate_content(text)
print(response.text)
# Out:
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 3284.49ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1268.31ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 786.02ms
# 年代の古い順に並べると、以下のようになります。
#
# *   **イ**　嵯峨天皇は，藤原冬嗣らを蔵人頭に任命した。
#     *   蔵人所の設置は**810年**（薬子の変直後）です。
#
# *   **ウ**　藤原良房は，承和の変後，藤原氏の中での北家の優位を確立した。
#     *   承和の変は**842年**です。
#
# *   **ア**　藤原時平は，策謀を用いて菅原道真を政界から追放した。
#     *   菅原道真の追放（昌泰の変）は**901年**です。
#
# したがって、年代の古い順は **イ → ウ → ア** です。

# %% [markdown]
# ## 42. 多肢選択問題の正解率
#
# [JMMLU](https://github.com/nlp-waseda/JMMLU) のいずれかの科目を大規模言語モデルに解答させ、その正解率を求めよ。

# %%
# !git clone https://github.com/nlp-waseda/JMMLU.git
# Out:
# fatal: destination path 'JMMLU' already exists and is not an empty directory.

# %%
import time, csv
from google.api_core import exceptions

# %%
file_path = "JMMLU/JMMLU/high_school_biology.csv"
correct_count = 0

with open(file_path, "r", encoding="UTF-8-sig") as f:
    reader = csv.reader(f)
    lines = list(reader)

i = 0

while i < len(lines):
  line = lines[i]
  time.sleep(60)     # 1分間に15リクエストくらい？

  question = line[0]
  choices = line[1:5]
  correct_answer = line[5]

  prompt = f"""以下の質問に答え、正解の記号（A, B, C, D）のみを回答してください。

  質問: {question}
  選択肢:
  A: {choices[0]}
  B: {choices[1]}
  C: {choices[2]}
  D: {choices[3]}
  回答:"""

  print(f"{i + 1}問目の解答を作成しています")

  try:
    response = model.generate_content(prompt)

    # 3. 判定（解答の先頭1文字が正解記号と一致するか）
    answer = response.text.strip()[0]
    if (answer == correct_answer):
        correct_count += 1

  except Exception as e:
    print(e)
    print("1分間停止します")
    time.sleep(60)
    print("処理を再開します")
    continue


  i += 1


# 4. 正解率の算出
accuracy = correct_count / len(lines)
print(f"正解率: {accuracy * 100:.2f}%")
# Out:
# 1問目の解答を作成しています
# 2問目の解答を作成しています
# 3問目の解答を作成しています
# 4問目の解答を作成しています
# 5問目の解答を作成しています
# 6問目の解答を作成しています
# 7問目の解答を作成しています
# 8問目の解答を作成しています
# 9問目の解答を作成しています
# 10問目の解答を作成しています
# 11問目の解答を作成しています
# 12問目の解答を作成しています
# 13問目の解答を作成しています
# 14問目の解答を作成しています
# 15問目の解答を作成しています
# 16問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 230.37ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 1.957208932s.
# 1分間停止します
# 処理を再開します
# 16問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 382.44ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 56.55615287s.
# 1分間停止します
# 処理を再開します
# 16問目の解答を作成しています
# 17問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 205.00ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 44.409619076s.
# 1分間停止します
# 処理を再開します
# 17問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 433.09ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 38.971376982s.
# 1分間停止します
# 処理を再開します
# 17問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 383.01ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 33.586190089s.
# 1分間停止します
# 処理を再開します
# 17問目の解答を作成しています
# 18問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 380.72ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 21.247022635s.
# 1分間停止します
# 処理を再開します
# 18問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 382.25ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 15.843271335s.
# 1分間停止します
# 処理を再開します
# 18問目の解答を作成しています
# 19問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 534.63ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 3.852368316s.
# 1分間停止します
# 処理を再開します
# 19問目の解答を作成しています
# 20問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 432.25ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 51.852634724s.
# 1分間停止します
# 処理を再開します
# 20問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 438.00ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 46.362984608s.
# 1分間停止します
# 処理を再開します
# 20問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 710.13ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 40.69278033s.
# 1分間停止します
# 処理を再開します
# 20問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 433.91ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 35.222943473s.
# 1分間停止します
# 処理を再開します
# 20問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 608.65ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 29.676342981s.
# 1分間停止します
# 処理を再開します
# 20問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1549.17ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 23.092278857s.
# 1分間停止します
# 処理を再開します
# 20問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 737.37ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 17.395274276s.
# 1分間停止します
# 処理を再開します
# 20問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1270.96ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 11.180251458s.
# 1分間停止します
# 処理を再開します
# 20問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 458.70ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 5.534766524s.
# 1分間停止します
# 処理を再開します
# 20問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 688.86ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 59.8470058s.
# 1分間停止します
# 処理を再開します
# 20問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 816.41ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 54.119720057s.
# 1分間停止します
# 処理を再開します
# 20問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 637.00ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 48.401851921s.
# 1分間停止します
# 処理を再開します
# 20問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 533.59ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 42.894059004s.
# 1分間停止します
# 処理を再開します
# 20問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 634.11ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 37.260117913s.
# 1分間停止します
# 処理を再開します
# 20問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 966.18ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 31.344916456s.
# 1分間停止します
# 処理を再開します
# 20問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 608.67ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 25.692366087s.
# 1分間停止します
# 処理を再開します
# 20問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 840.08ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 19.831751446s.
# 1分間停止します
# 処理を再開します
# 20問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 814.48ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 14.033343101s.
# 1分間停止します
# 処理を再開します
# 20問目の解答を作成しています
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 433.65ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 8.501544595s.
# 1分間停止します
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# /tmp/ipykernel_63302/663580947.py in <cell line: 0>()
#      30   try:
# ---> 31     response = model.generate_content(prompt)
#      32
#
# /usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
#
# /usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py in generate_content(self, request, model, contents, retry, timeout, metadata)
#     834         # Send the request.
# --> 835         response = rpc(
#     836             request,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, compression, *args, **kwargs)
#     127
# --> 128         return wrapped_func(*args, **kwargs)
#     129
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_wrapped_func(*args, **kwargs)
#     293             )
# --> 294             return retry_target(
#     295                 target,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     155             # defer to shared logic for handling errors
# --> 156             next_sleep = _retry_error_helper(
#     157                 exc,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     215         )
# --> 216         raise final_exc from source_exc
#     217     if on_error_fn is not None:
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     146         try:
# --> 147             result = target()
#     148             if inspect.isawaitable(result):
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py in func_with_timeout(*args, **kwargs)
#     129
# --> 130             return func(*args, **kwargs)
#     131
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      54         try:
# ---> 55             return callable_(*args, **kwargs)
#      56         except grpc.RpcError as exc:
#
# /usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py in __call__(self, request, retry, timeout, metadata)
#    1160             if response.status_code >= 400:
# -> 1161                 raise core_exceptions.from_http_response(response)
#    1162
#
# TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite
# Please retry in 8.501544595s.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_63302/663580947.py in <cell line: 0>()
#      39     print(e)
#      40     print("1分間停止します")
# ---> 41     time.sleep(60)
#      42     print("処理を再開します")
#      43     continue
#
# KeyboardInterrupt:

# %% [markdown]
# ## 43. 応答のバイアス
#
# 問題42において、実験設定を変化させると正解率が変化するかどうかを調べよ。実験設定の例としては、大規模言語モデルの温度パラメータ、プロンプト、多肢選択肢の順番、多肢選択肢の記号などが考えられる。

# %% [markdown]
# 正解の選択肢を全てDに入れ替えて解答させる例。

# %% [markdown]
# ## 44. 対話
#
# 以下の問いかけに対する応答を生成せよ。
#
# > つばめちゃんは渋谷駅から東急東横線に乗り、自由が丘駅で乗り換えました。東急大井町線の大井町方面の電車に乗り換えたとき、各駅停車に乗車すべきところ、間違えて急行に乗車してしまったことに気付きました。自由が丘の次の急行停車駅で降車し、反対方向の電車で一駅戻った駅がつばめちゃんの目的地でした。目的地の駅の名前を答えてください。
#
# 参考: [東急線・みなとみらい線路線案内](https://www.tokyu.co.jp/railway/station/map.html)

# %%
text = """
つばめちゃんは渋谷駅から東急東横線に乗り、自由が丘駅で乗り換えました。東急大井町線の大井町方面の電車に乗り換えたとき、各駅停車に乗車すべきところ、間違えて急行に乗車してしまったことに気付きました。自由が丘の次の急行停車駅で降車し、反対方向の電車で一駅戻った駅がつばめちゃんの目的地でした。目的地の駅の名前を答えてください。
"""

# %%
model = genai.GenerativeModel("gemini-2.5-flash-lite")
chat = model.start_chat(history=[])
response = chat.send_message(text)
print(response.text)
# Out:
# つばめちゃんの目的地は **荏原町駅** です。
#
# 解説は以下の通りです。
#
# 1.  **自由が丘駅での乗り換え:** つばめちゃんは自由が丘駅で東急東横線から東急大井町線に乗り換えました。
# 2.  **間違えて乗車した電車:** 大井町方面の電車で、本来は各駅停車に乗るべきところ、急行に乗ってしまいました。
# 3.  **自由が丘の次の急行停車駅:** 東急大井町線で自由が丘駅の次に急行が停車する駅は **旗の台駅** です。
# 4.  **旗の台駅で降車:** つばめちゃんは旗の台駅で降りました。
# 5.  **反対方向の電車で一駅戻る:** 旗の台駅から大井町方面とは反対方向（つまり、溝の口方面）に一駅戻ります。
# 6.  **旗の台駅の一つ手前の駅:** 旗の台駅の一つ手前の駅（溝の口方面）は **荏原町駅** です。
#
# したがって、つばめちゃんの目的地は荏原町駅です。

# %% [markdown]
# ## 45. マルチターン対話

# %% [markdown]
# 先ほどの応答に続けて、以下の追加の問いかけに対する応答を生成せよ。
#
# > さらに、つばめちゃんが自由が丘駅で乗り換えたとき、先ほどとは反対方向の急行電車に間違って乗車してしまった場合を考えます。目的地の駅に向かうため、自由が丘の次の急行停車駅で降車した後、反対方向の各駅停車に乗車した場合、何駅先の駅で降りれば良いでしょうか？

# %%
text = """
さらに、つばめちゃんが自由が丘駅で乗り換えたとき、先ほどとは反対方向の急行電車に間違って乗車してしまった場合を考えます。目的地の駅に向かうため、自由が丘の次の急行停車駅で降車した後、反対方向の各駅停車に乗車した場合、何駅先の駅で降りれば良いでしょうか？
"""

# %%
response = chat.send_message(text)
print(response.text)
# Out:
# この場合、つばめちゃんは **3駅先** の駅で降りる必要があります。
#
# 解説は以下の通りです。
#
# 1.  **自由が丘駅での乗り換え（今回の場合）:** つばめちゃんは自由が丘駅で東急東横線から東急大井町線に乗り換えました。
# 2.  **間違えて乗車した電車（今回の場合）:** 大井町方面ではなく、**反対方向**（溝の口方面）の**急行**電車に間違えて乗車してしまいました。
# 3.  **自由が丘の次の急行停車駅:** 東急大井町線で自由が丘駅の次に急行が停車する駅は、大井町方面とは反対方向（溝の口方面）に進んだ場合、**九品仏駅** です。
# 4.  **九品仏駅で降車:** つばめちゃんは九品仏駅で降りました。
# 5.  **反対方向の各駅停車に乗車:** 九品仏駅から、本来乗るべきだった大井町方面の**各駅停車**に乗車します。
# 6.  **目的地への到着:** つばめちゃんの目的地は、前回と同様、**荏原町駅** です。
#
# それでは、九品仏駅から荏原町駅まで、大井町方面の各駅停車で何駅かかるか数えてみましょう。
#
# *   九品仏（乗車駅）
# *   尾山台
# *   等々力
# *   **荏原町** （目的地）
#
# 九品仏駅から荏原町駅までは、途中に **尾山台駅** と **等々力駅** の2駅があります。
#
# したがって、九品仏駅から各駅停車に乗車した場合、目的地である荏原町駅は **3駅先** になります。

# %% [markdown]
# ## 46. 川柳の生成
#
# 適当なお題を設定し、川柳の案を10個作成せよ。

# %%
text = "「梅雨」というお題で、川柳を10個作成してください。"

# %%
model = genai.GenerativeModel("gemini-2.5-flash-lite")
response = chat.send_message(text)
print(response.text)
# Out:
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 2616.18ms
# はい、承知いたしました。「梅雨」というお題で川柳を10個作成します。
#
# 1.  空じゅうたん じめっと湿度に 息もれる
# 2.  紫陽花が 憂鬱晴らす 色を添え
# 3.  雨粒のリズム 窓辺に聴けば
# 4.  傘の花 街を彩る 憂いの色
# 5.  洗濯物 乾かぬままに 溜まってく
# 6.  カエル鳴く 恵みの雨か 憂いか
# 7.  虹を待つ 心にぽっと 光探す
# 8.  雨音に 読書進むか 眠気覚ます
# 9.  じめじめと 湿気と戦う 寝苦しさ
# 10. 晴れ間待つ 青空願う 心模様

# %% [markdown]
# ## 47. LLMによる評価
#
# 大規模言語モデルを評価者（ジャッジ）として、問題46の川柳の面白さを10段階で評価せよ。

# %%
text = f"""
以下の川柳の面白さを10段階で評価してください。
1.  空じゅうたん じめっと湿度に 息もれる
2.  紫陽花が 憂鬱晴らす 色を添え
3.  雨粒のリズム 窓辺に聴けば
4.  傘の花 街を彩る 憂いの色
5.  洗濯物 乾かぬままに 溜まってく
6.  カエル鳴く 恵みの雨か 憂いか
7.  虹を待つ 心にぽっと 光探す
8.  雨音に 読書進むか 眠気覚ます
9.  じめじめと 湿気と戦う 寝苦しさ
10. 晴れ間待つ 青空願う 心模様
"""

# %%
response = chat.send_message(text)
print(response.text)
# Out:
# 承知いたしました。それぞれの川柳について、面白さを10段階で評価し、その理由も添えて解説します。面白さの基準としては、意外性、共感性、情景描写の巧みさ、言葉の響きなどを考慮しました。
#
# ---
#
# **1. 空じゅうたん じめっと湿度に 息もれる**
#
# *   **面白さ評価：7/10**
# *   **理由：** 「空じゅうたん」という比喩がユニークで、梅雨のどんよりとした空をうまく表現しています。湿度で息苦しさを感じる情景も共感を呼び、言葉の響きも湿っぽさが伝わってきて面白いです。
#
# **2. 紫陽花が 憂鬱晴らす 色を添え**
#
# *   **面白さ評価：5/10**
# *   **理由：** 紫陽花が梅雨の憂鬱さを晴らしてくれるという情景は綺麗ですが、やや定番の表現かもしれません。もう少し意外性やひねりがあると、より面白みが増すでしょう。
#
# **3. 雨粒のリズム 窓辺に聴けば**
#
# *   **面白さ評価：4/10**
# *   **理由：** 雨音を聴くという情景は共感できますが、特筆すべき面白さは感じられません。静かで落ち着いた雰囲気は伝わりますが、もう少し具体的な描写や感情があると良いかもしれません。
#
# **4. 傘の花 街を彩る 憂いの色**
#
# *   **面白さ評価：6/10**
# *   **理由：** 「傘の花」という言葉が、雨の日の街の賑わいを視覚的に捉えていて面白いです。ただ、「憂いの色」という表現が少し説明的で、もう少し詩的な余韻があっても良いかもしれません。
#
# **5. 洗濯物 乾かぬままに 溜まってく**
#
# *   **面白さ評価：8/10**
# *   **理由：** 梅雨時の誰もが経験するであろう、非常に共感性の高いあるあるネタです。その切実さ、无奈さがストレートに表現されており、思わず「わかる！」と声が出てしまうような面白さがあります。
#
# **6. カエル鳴く 恵みの雨か 憂いか**
#
# *   **面白さ評価：7/10**
# *   **理由：** カエルの鳴き声を「恵みの雨」と捉えるか、「憂い」と捉えるかという対比が面白いです。自然の音と人間の感情を重ね合わせた視点がユニークです。
#
# **7. 虹を待つ 心にぽっと 光探す**
#
# *   **面白さ評価：6/10**
# *   **理由：** 梅雨の晴れ間や虹を待つ希望が、静かに、しかし確かに表現されています。「ぽっと光探す」という言葉に、ささやかながらも前向きな気持ちが感じられて好感が持てます。
#
# **8. 雨音に 読書進むか 眠気覚ます**
#
# *   **面白さ評価：7/10**
# *   **理由：** 雨音によって読書が進むのか、それとも眠気を誘われるのか、という二択の状況が、多くの人に経験のある「あるある」として面白く、共感を呼びます。どちらに転ぶかわからない、その曖昧さが良いです。
#
# **9. じめじめと 湿気と戦う 寝苦しさ**
#
# *   **面白さ評価：8/10**
# *   **理由：** 物理的な「湿気との戦い」という表現が、寝苦しさの辛さを生々しく伝えています。言葉の響きも「じめじめ」と湿っぽく、梅雨の不快な体験を的確に描写していて面白いです。
#
# **10. 晴れ間待つ 青空願う 心模様**
#
# *   **面白さ評価：5/10**
# *   **理由：** 梅雨の時期に多くの人が抱く素直な願望ですが、表現としてはやや直接的で、もう少しひねりや比喩があると、より心に響く面白さになるでしょう。
#
# ---
#
# **総合的に見ると、**
#
# *   **「5. 洗濯物 乾かぬままに 溜まってく」** と **「9. じめじめと 湿気と戦う 寝苦しさ」** が、梅雨の時期の日常的な不快感やあるあるを的確に捉えている点で、最も面白さと共感性が高いと言えます。
# *   **「1. 空じゅうたん じめっと湿度に 息もれる」** や **「6. カエル鳴く 恵みの雨か 憂いか」** も、比喩や対比が効いており、面白い視点を提供しています。

# %% [markdown]
# ## 48. LLMによる評価の頑健性
#
# 問題47で行ったLLMによるテキストの評価に関して、その頑健さ（脆弱さ）を調査せよ。最も単純な方法は、同じ評価を何回か繰り返した時のスコアの分散を調べることであろう。また、川柳の末尾に特定のメッセージを追加することで、評価スコアを恣意的に操作することも可能であろう。

# %% [markdown]
# ## 49. トークン化
#
# 以下の文章（夏目漱石の『吾輩は猫である』の冒頭部分）のトークン数を計測せよ。
#
# >　吾輩は猫である。名前はまだ無い。
# >
# >　どこで生れたかとんと見当がつかぬ。何でも薄暗いじめじめした所でニャーニャー泣いていた事だけは記憶している。吾輩はここで始めて人間というものを見た。しかもあとで聞くとそれは書生という人間中で一番獰悪な種族であったそうだ。この書生というのは時々我々を捕えて煮て食うという話である。しかしその当時は何という考もなかったから別段恐しいとも思わなかった。ただ彼の掌に載せられてスーと持ち上げられた時何だかフワフワした感じがあったばかりである。掌の上で少し落ちついて書生の顔を見たのがいわゆる人間というものの見始であろう。この時妙なものだと思った感じが今でも残っている。第一毛をもって装飾されべきはずの顔がつるつるしてまるで薬缶だ。その後猫にもだいぶ逢ったがこんな片輪には一度も出会わした事がない。のみならず顔の真中があまりに突起している。そうしてその穴の中から時々ぷうぷうと煙を吹く。どうも咽せぽくて実に弱った。これが人間の飲む煙草というものである事はようやくこの頃知った。

# %%
text = """
　吾輩は猫である。名前はまだ無い。

　どこで生れたかとんと見当がつかぬ。何でも薄暗いじめじめした所でニャーニャー泣いていた事だけは記憶している。吾輩はここで始めて人間というものを見た。しかもあとで聞くとそれは書生という人間中で一番獰悪な種族であったそうだ。この書生というのは時々我々を捕えて煮て食うという話である。しかしその当時は何という考もなかったから別段恐しいとも思わなかった。ただ彼の掌に載せられてスーと持ち上げられた時何だかフワフワした感じがあったばかりである。掌の上で少し落ちついて書生の顔を見たのがいわゆる人間というものの見始であろう。この時妙なものだと思った感じが今でも残っている。第一毛をもって装飾されべきはずの顔がつるつるしてまるで薬缶だ。その後猫にもだいぶ逢ったがこんな片輪には一度も出会わした事がない。のみならず顔の真中があまりに突起している。そうしてその穴の中から時々ぷうぷうと煙を吹く。どうも咽せぽくて実に弱った。これが人間の飲む煙草というものである事はようやくこの頃知った。
"""

# %%
token_info = model.count_tokens(prompt)
print(token_info)
# Out:
# total_tokens: 156
